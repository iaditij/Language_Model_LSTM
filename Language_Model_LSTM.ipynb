# %%
from numpy import array
from keras.preprocessing.text import Tokenizer
from keras.utils import to_categorical
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Embedding
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # TASK
# Language Model - $P(X_{t+1}|X_{1:t})$. Given a sequence of text, we try to model the next word. If we do this process recursively, we will be able to generate language.

# %%
data = """ Jack and Jill went up the hill\n
         To fetch a pail of water\n
         Jack fell down and broke his crown\n
         And Jill came tumbling after\n """

# %%
data = """To be, or not to be, that is the question\n
Whether it is nobler in the mind to suffer\n
The slings and arrows of outrageous fortune\n
Or to take arms against a sea of troubles\n
And by opposing end them. To die—to sleep \n
No more; and by a sleep to say we end \n
The heart-ache and the thousand natural shocks \n
That flesh is heir to: 'tis a consummation \n
Devoutly to be wish'd. To die, to sleep \n
To sleep, perchance to dream—ay, there's the rub \n
For in that sleep of death what dreams may come \n 
When we have shuffled off this mortal coil\n
Must give us pause—there's the respect\n
That makes calamity of so long life\n"""

# %% [markdown]
# SEQUENCE GENERATOR

# %%
# generate a sequence from a language model
def generate_seq(model, tokenizer, max_length, seed_text, n_words):
    in_text = seed_text
    # generate a fixed number of words
    for _ in range(n_words):
    # encode the text as integer
        encoded = tokenizer.texts_to_sequences([in_text])[0]
        # pre-pad sequences to a fixed length
        encoded = pad_sequences([encoded], maxlen=max_length, padding='pre')
        # predict probabilities for each word
        yhat = model.predict_classes(encoded, verbose=0)
        # map predicted word index to word
        out_word = ''
        for word, index in tokenizer.word_index.items():
            if index == yhat:
                out_word = word
                break
        # append to input
        in_text += ' ' + out_word
    return in_text

# %% [markdown]
# TOKENIZE

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts([data])
# determine the vocabulary size
vocab_size = len(tokenizer.word_index) + 1
print('Vocabulary Size: %d' % vocab_size)
# create line-based sequences
sequences = list()
for line in data.split('\n'):
    encoded = tokenizer.texts_to_sequences([line])[0]
    for i in range(1, len(encoded)):
        sequence = encoded[:i+1]
        sequences.append(sequence)
print('Total Sequences: %d' % len(sequences))
# Out:
# Vocabulary Size: 76
# Total Sequences: 102

# %% [markdown]
# PAD SENTENCES TO SAME LENGTH

# %%
# pad input sequences
max_length = max([len(seq) for seq in sequences])
sequences = pad_sequences(sequences, maxlen=max_length, padding='pre')
print('Max Sequence Length: %d' % max_length)
# Out:
# Max Sequence Length: 10

# %% [markdown]
# SPLIT INPUTS

# %%
# split into input and output elements
sequences = array(sequences)
X, y = sequences[:,:-1],sequences[:,-1]
y = to_categorical(y, num_classes=vocab_size)# define model

# %% [markdown]
# MODEL

# %%
# define model
model = Sequential()
model.add(Embedding(vocab_size, 10, input_length=max_length-1))
model.add(LSTM(50))
model.add(Dense(vocab_size, activation='softmax'))
print(model.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 9, 10)             760
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 50)                12200
# _________________________________________________________________
# dense_1 (Dense)              (None, 76)                3876
# =================================================================
# Total params: 16,836
# Trainable params: 16,836
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# TRAIN

# %%
# compile network
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
# fit network
model.fit(X, y, epochs=500, verbose=2)
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/indexed_slices.py:434: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Epoch 1/500
#  - 1s - loss: 4.3314 - accuracy: 0.0392
# Epoch 2/500
#  - 0s - loss: 4.3270 - accuracy: 0.0980
# Epoch 3/500
#  - 0s - loss: 4.3229 - accuracy: 0.0980
# Epoch 4/500
#  - 0s - loss: 4.3184 - accuracy: 0.0980
# Epoch 5/500
#  - 0s - loss: 4.3135 - accuracy: 0.0980
# Epoch 6/500
#  - 0s - loss: 4.3069 - accuracy: 0.0980
# Epoch 7/500
#  - 0s - loss: 4.2985 - accuracy: 0.0980
# Epoch 8/500
#  - 0s - loss: 4.2871 - accuracy: 0.0980
# Epoch 9/500
#  - 0s - loss: 4.2700 - accuracy: 0.0980
# Epoch 10/500
#  - 0s - loss: 4.2441 - accuracy: 0.0980
# Epoch 11/500
#  - 0s - loss: 4.2044 - accuracy: 0.0980
# Epoch 12/500
#  - 0s - loss: 4.1479 - accuracy: 0.0980
# Epoch 13/500
#  - 0s - loss: 4.0818 - accuracy: 0.0980
# Epoch 14/500
#  - 0s - loss: 4.0397 - accuracy: 0.0980
# Epoch 15/500
#  - 0s - loss: 4.0566 - accuracy: 0.0980
# Epoch 16/500
#  - 0s - loss: 4.0458 - accuracy: 0.0980
# Epoch 17/500
#  - 0s - loss: 4.0165 - accuracy: 0.0980
# Epoch 18/500
#  - 0s - loss: 4.0041 - accuracy: 0.0980
# Epoch 19/500
#  - 0s - loss: 4.0034 - accuracy: 0.0980
# Epoch 20/500
#  - 0s - loss: 3.9925 - accuracy: 0.0980
# Epoch 21/500
#  - 0s - loss: 3.9820 - accuracy: 0.0980
# Epoch 22/500
#  - 0s - loss: 3.9746 - accuracy: 0.0980
# Epoch 23/500
#  - 0s - loss: 3.9730 - accuracy: 0.0980
# Epoch 24/500
#  - 0s - loss: 3.9652 - accuracy: 0.0980
# Epoch 25/500
#  - 0s - loss: 3.9546 - accuracy: 0.0980
# Epoch 26/500
#  - 0s - loss: 3.9464 - accuracy: 0.0980
# Epoch 27/500
#  - 0s - loss: 3.9418 - accuracy: 0.0980
# Epoch 28/500
#  - 0s - loss: 3.9299 - accuracy: 0.0980
# Epoch 29/500
#  - 0s - loss: 3.9200 - accuracy: 0.0980
# Epoch 30/500
#  - 0s - loss: 3.9136 - accuracy: 0.0980
# Epoch 31/500
#  - 0s - loss: 3.9055 - accuracy: 0.0980
# Epoch 32/500
#  - 0s - loss: 3.8919 - accuracy: 0.1078
# Epoch 33/500
#  - 0s - loss: 3.8843 - accuracy: 0.1078
# Epoch 34/500
#  - 0s - loss: 3.8725 - accuracy: 0.1078
# Epoch 35/500
#  - 0s - loss: 3.8580 - accuracy: 0.1078
# Epoch 36/500
#  - 0s - loss: 3.8452 - accuracy: 0.1078
# Epoch 37/500
#  - 0s - loss: 3.8319 - accuracy: 0.1078
# Epoch 38/500
#  - 0s - loss: 3.8165 - accuracy: 0.1078
# Epoch 39/500
#  - 0s - loss: 3.8002 - accuracy: 0.1176
# Epoch 40/500
#  - 0s - loss: 3.7806 - accuracy: 0.1176
# Epoch 41/500
#  - 0s - loss: 3.7639 - accuracy: 0.1275
# Epoch 42/500
#  - 0s - loss: 3.7461 - accuracy: 0.1275
# Epoch 43/500
#  - 0s - loss: 3.7234 - accuracy: 0.1275
# Epoch 44/500
#  - 0s - loss: 3.7014 - accuracy: 0.1275
# Epoch 45/500
#  - 0s - loss: 3.6838 - accuracy: 0.1176
# Epoch 46/500
#  - 0s - loss: 3.6669 - accuracy: 0.1176
# Epoch 47/500
#  - 0s - loss: 3.6451 - accuracy: 0.1275
# Epoch 48/500
#  - 0s - loss: 3.6357 - accuracy: 0.1275
# Epoch 49/500
#  - 0s - loss: 3.6084 - accuracy: 0.1373
# Epoch 50/500
#  - 0s - loss: 3.5860 - accuracy: 0.1373
# Epoch 51/500
#  - 0s - loss: 3.5688 - accuracy: 0.1373
# Epoch 52/500
#  - 0s - loss: 3.5555 - accuracy: 0.1275
# Epoch 53/500
#  - 0s - loss: 3.5412 - accuracy: 0.1373
# Epoch 54/500
#  - 0s - loss: 3.5137 - accuracy: 0.1471
# Epoch 55/500
#  - 0s - loss: 3.5018 - accuracy: 0.1471
# Epoch 56/500
#  - 0s - loss: 3.4965 - accuracy: 0.1471
# Epoch 57/500
#  - 0s - loss: 3.4753 - accuracy: 0.1471
# Epoch 58/500
#  - 0s - loss: 3.4581 - accuracy: 0.1569
# Epoch 59/500
#  - 0s - loss: 3.4499 - accuracy: 0.1569
# Epoch 60/500
#  - 0s - loss: 3.4136 - accuracy: 0.1569
# Epoch 61/500
#  - 0s - loss: 3.4115 - accuracy: 0.1569
# Epoch 62/500
#  - 0s - loss: 3.3922 - accuracy: 0.1569
# Epoch 63/500
#  - 0s - loss: 3.3592 - accuracy: 0.1667
# Epoch 64/500
#  - 0s - loss: 3.3878 - accuracy: 0.1863
# Epoch 65/500
#  - 0s - loss: 3.3524 - accuracy: 0.1863
# Epoch 66/500
#  - 0s - loss: 3.3292 - accuracy: 0.1569
# Epoch 67/500
#  - 0s - loss: 3.3077 - accuracy: 0.1765
# Epoch 68/500
#  - 0s - loss: 3.3003 - accuracy: 0.1863
# Epoch 69/500
#  - 0s - loss: 3.2759 - accuracy: 0.1667
# Epoch 70/500
#  - 0s - loss: 3.2626 - accuracy: 0.1667
# Epoch 71/500
#  - 0s - loss: 3.2445 - accuracy: 0.1765
# Epoch 72/500
#  - 0s - loss: 3.2328 - accuracy: 0.1765
# Epoch 73/500
#  - 0s - loss: 3.2077 - accuracy: 0.1863
# Epoch 74/500
#  - 0s - loss: 3.2031 - accuracy: 0.1765
# Epoch 75/500
#  - 0s - loss: 3.1774 - accuracy: 0.1863
# Epoch 76/500
#  - 0s - loss: 3.1786 - accuracy: 0.2059
# Epoch 77/500
#  - 0s - loss: 3.1436 - accuracy: 0.1961
# Epoch 78/500
#  - 0s - loss: 3.1636 - accuracy: 0.1863
# Epoch 79/500
#  - 0s - loss: 3.1180 - accuracy: 0.2353
# Epoch 80/500
#  - 0s - loss: 3.1144 - accuracy: 0.2157
# Epoch 81/500
#  - 0s - loss: 3.0990 - accuracy: 0.2255
# Epoch 82/500
#  - 0s - loss: 3.0823 - accuracy: 0.2059
# Epoch 83/500
#  - 0s - loss: 3.0667 - accuracy: 0.2059
# Epoch 84/500
#  - 0s - loss: 3.0415 - accuracy: 0.2059
# Epoch 85/500
#  - 0s - loss: 3.0347 - accuracy: 0.2059
# Epoch 86/500
#  - 0s - loss: 3.0271 - accuracy: 0.2255
# Epoch 87/500
#  - 0s - loss: 3.0035 - accuracy: 0.2255
# Epoch 88/500
#  - 0s - loss: 2.9889 - accuracy: 0.2059
# Epoch 89/500
#  - 0s - loss: 2.9749 - accuracy: 0.2255
# Epoch 90/500
#  - 0s - loss: 2.9526 - accuracy: 0.2157
# Epoch 91/500
#  - 0s - loss: 2.9395 - accuracy: 0.2353
# Epoch 92/500
#  - 0s - loss: 2.9425 - accuracy: 0.2451
# Epoch 93/500
#  - 0s - loss: 2.9154 - accuracy: 0.2451
# Epoch 94/500
#  - 0s - loss: 2.8921 - accuracy: 0.2549
# Epoch 95/500
#  - 0s - loss: 2.8866 - accuracy: 0.2549
# Epoch 96/500
#  - 0s - loss: 2.8653 - accuracy: 0.2549
# Epoch 97/500
#  - 0s - loss: 2.8554 - accuracy: 0.2549
# Epoch 98/500
#  - 0s - loss: 2.8344 - accuracy: 0.2451
# Epoch 99/500
#  - 0s - loss: 2.8444 - accuracy: 0.2157
# Epoch 100/500
#  - 0s - loss: 2.8180 - accuracy: 0.2549
# Epoch 101/500
#  - 0s - loss: 2.8007 - accuracy: 0.2549
# Epoch 102/500
#  - 0s - loss: 2.8131 - accuracy: 0.2451
# Epoch 103/500
#  - 0s - loss: 2.8073 - accuracy: 0.2647
# Epoch 104/500
#  - 0s - loss: 2.7700 - accuracy: 0.2549
# Epoch 105/500
#  - 0s - loss: 2.7551 - accuracy: 0.2843
# Epoch 106/500
#  - 0s - loss: 2.7482 - accuracy: 0.2745
# Epoch 107/500
#  - 0s - loss: 2.7222 - accuracy: 0.3039
# Epoch 108/500
#  - 0s - loss: 2.7185 - accuracy: 0.2941
# Epoch 109/500
#  - 0s - loss: 2.6944 - accuracy: 0.2843
# Epoch 110/500
#  - 0s - loss: 2.6865 - accuracy: 0.3039
# Epoch 111/500
#  - 0s - loss: 2.6823 - accuracy: 0.2843
# Epoch 112/500
#  - 0s - loss: 2.6748 - accuracy: 0.2745
# Epoch 113/500
#  - 0s - loss: 2.6551 - accuracy: 0.2941
# Epoch 114/500
#  - 0s - loss: 2.6248 - accuracy: 0.3137
# Epoch 115/500
#  - 0s - loss: 2.6458 - accuracy: 0.3333
# Epoch 116/500
#  - 0s - loss: 2.6138 - accuracy: 0.2941
# Epoch 117/500
#  - 0s - loss: 2.6151 - accuracy: 0.3137
# Epoch 118/500
#  - 0s - loss: 2.5998 - accuracy: 0.3333
# Epoch 119/500
#  - 0s - loss: 2.5777 - accuracy: 0.3137
# Epoch 120/500
#  - 0s - loss: 2.5692 - accuracy: 0.3235
# Epoch 121/500
#  - 0s - loss: 2.5830 - accuracy: 0.3529
# Epoch 122/500
#  - 0s - loss: 2.5399 - accuracy: 0.3627
# Epoch 123/500
#  - 0s - loss: 2.5362 - accuracy: 0.3431
# Epoch 124/500
#  - 0s - loss: 2.5366 - accuracy: 0.3529
# Epoch 125/500
#  - 0s - loss: 2.5027 - accuracy: 0.3333
# Epoch 126/500
#  - 0s - loss: 2.5111 - accuracy: 0.3039
# Epoch 127/500
#  - 0s - loss: 2.4965 - accuracy: 0.3529
# Epoch 128/500
#  - 0s - loss: 2.4856 - accuracy: 0.3333
# Epoch 129/500
#  - 0s - loss: 2.4599 - accuracy: 0.3333
# Epoch 130/500
#  - 0s - loss: 2.4538 - accuracy: 0.3333
# Epoch 131/500
#  - 0s - loss: 2.4492 - accuracy: 0.3235
# Epoch 132/500
#  - 0s - loss: 2.4296 - accuracy: 0.3137
# Epoch 133/500
#  - 0s - loss: 2.4289 - accuracy: 0.3235
# Epoch 134/500
#  - 0s - loss: 2.4201 - accuracy: 0.3333
# Epoch 135/500
#  - 0s - loss: 2.4061 - accuracy: 0.3137
# Epoch 136/500
#  - 0s - loss: 2.3933 - accuracy: 0.3431
# Epoch 137/500
#  - 0s - loss: 2.3836 - accuracy: 0.3824
# Epoch 138/500
#  - 0s - loss: 2.3710 - accuracy: 0.3627
# Epoch 139/500
#  - 0s - loss: 2.3577 - accuracy: 0.3824
# Epoch 140/500
#  - 0s - loss: 2.3498 - accuracy: 0.4020
# Epoch 141/500
#  - 0s - loss: 2.3513 - accuracy: 0.4020
# Epoch 142/500
#  - 0s - loss: 2.3327 - accuracy: 0.4118
# Epoch 143/500
#  - 0s - loss: 2.3342 - accuracy: 0.4216
# Epoch 144/500
#  - 0s - loss: 2.3180 - accuracy: 0.4020
# Epoch 145/500
#  - 0s - loss: 2.3383 - accuracy: 0.4118
# Epoch 146/500
#  - 0s - loss: 2.2960 - accuracy: 0.4510
# Epoch 147/500
#  - 0s - loss: 2.2940 - accuracy: 0.4118
# Epoch 148/500
#  - 0s - loss: 2.2859 - accuracy: 0.4314
# Epoch 149/500
#  - 0s - loss: 2.2637 - accuracy: 0.4510
# Epoch 150/500
#  - 0s - loss: 2.2576 - accuracy: 0.4118
# Epoch 151/500
#  - 0s - loss: 2.2462 - accuracy: 0.4314
# Epoch 152/500
#  - 0s - loss: 2.2376 - accuracy: 0.4314
# Epoch 153/500
#  - 0s - loss: 2.2466 - accuracy: 0.4412
# Epoch 154/500
#  - 0s - loss: 2.2185 - accuracy: 0.4412
# Epoch 155/500
#  - 0s - loss: 2.2208 - accuracy: 0.4510
# Epoch 156/500
#  - 0s - loss: 2.2113 - accuracy: 0.4216
# Epoch 157/500
#  - 0s - loss: 2.2156 - accuracy: 0.4020
# Epoch 158/500
#  - 0s - loss: 2.1955 - accuracy: 0.4608
# Epoch 159/500
#  - 0s - loss: 2.1823 - accuracy: 0.4608
# Epoch 160/500
#  - 0s - loss: 2.1808 - accuracy: 0.4608
# Epoch 161/500
#  - 0s - loss: 2.1573 - accuracy: 0.4608
# Epoch 162/500
#  - 0s - loss: 2.1726 - accuracy: 0.4118
# Epoch 163/500
#  - 0s - loss: 2.1672 - accuracy: 0.4706
# Epoch 164/500
#  - 0s - loss: 2.1552 - accuracy: 0.4706
# Epoch 165/500
#  - 0s - loss: 2.1369 - accuracy: 0.4804
# Epoch 166/500
#  - 0s - loss: 2.1513 - accuracy: 0.4902
# Epoch 167/500
#  - 0s - loss: 2.1168 - accuracy: 0.5098
# Epoch 168/500
#  - 0s - loss: 2.1140 - accuracy: 0.4804
# Epoch 169/500
#  - 0s - loss: 2.1039 - accuracy: 0.4902
# Epoch 170/500
#  - 0s - loss: 2.0913 - accuracy: 0.4706
# Epoch 171/500
#  - 0s - loss: 2.0827 - accuracy: 0.4804
# Epoch 172/500
#  - 0s - loss: 2.0782 - accuracy: 0.4902
# Epoch 173/500
#  - 0s - loss: 2.0714 - accuracy: 0.5000
# Epoch 174/500
#  - 0s - loss: 2.0594 - accuracy: 0.4902
# Epoch 175/500
#  - 0s - loss: 2.0577 - accuracy: 0.4804
# Epoch 176/500
#  - 0s - loss: 2.0454 - accuracy: 0.5000
# Epoch 177/500
#  - 0s - loss: 2.0593 - accuracy: 0.4902
# Epoch 178/500
#  - 0s - loss: 2.0297 - accuracy: 0.4902
# Epoch 179/500
#  - 0s - loss: 2.0319 - accuracy: 0.4804
# Epoch 180/500
#  - 0s - loss: 2.0246 - accuracy: 0.4902
# Epoch 181/500
#  - 0s - loss: 2.0115 - accuracy: 0.4804
# Epoch 182/500
#  - 0s - loss: 1.9968 - accuracy: 0.4902
# Epoch 183/500
#  - 0s - loss: 1.9891 - accuracy: 0.5196
# Epoch 184/500
#  - 0s - loss: 1.9874 - accuracy: 0.5392
# Epoch 185/500
#  - 0s - loss: 1.9780 - accuracy: 0.5294
# Epoch 186/500
#  - 0s - loss: 1.9733 - accuracy: 0.5196
# Epoch 187/500
#  - 0s - loss: 1.9632 - accuracy: 0.5196
# Epoch 188/500
#  - 0s - loss: 1.9593 - accuracy: 0.4902
# Epoch 189/500
#  - 0s - loss: 1.9537 - accuracy: 0.4804
# Epoch 190/500
#  - 0s - loss: 1.9505 - accuracy: 0.5000
# Epoch 191/500
#  - 0s - loss: 1.9438 - accuracy: 0.5098
# Epoch 192/500
#  - 0s - loss: 1.9336 - accuracy: 0.5196
# Epoch 193/500
#  - 0s - loss: 1.9241 - accuracy: 0.5098
# Epoch 194/500
#  - 0s - loss: 1.9185 - accuracy: 0.5098
# Epoch 195/500
#  - 0s - loss: 1.9100 - accuracy: 0.5098
# Epoch 196/500
#  - 0s - loss: 1.9083 - accuracy: 0.4902
# Epoch 197/500
#  - 0s - loss: 1.8944 - accuracy: 0.5000
# Epoch 198/500
#  - 0s - loss: 1.9062 - accuracy: 0.5000
# Epoch 199/500
#  - 0s - loss: 1.8843 - accuracy: 0.5490
# Epoch 200/500
#  - 0s - loss: 1.8791 - accuracy: 0.5392
# Epoch 201/500
#  - 0s - loss: 1.8699 - accuracy: 0.5392
# Epoch 202/500
#  - 0s - loss: 1.8655 - accuracy: 0.5490
# Epoch 203/500
#  - 0s - loss: 1.8564 - accuracy: 0.5294
# Epoch 204/500
#  - 0s - loss: 1.8525 - accuracy: 0.5294
# Epoch 205/500
#  - 0s - loss: 1.8444 - accuracy: 0.5588
# Epoch 206/500
#  - 0s - loss: 1.8319 - accuracy: 0.5490
# Epoch 207/500
#  - 0s - loss: 1.8293 - accuracy: 0.5588
# Epoch 208/500
#  - 0s - loss: 1.8278 - accuracy: 0.5588
# Epoch 209/500
#  - 0s - loss: 1.8190 - accuracy: 0.5294
# Epoch 210/500
#  - 0s - loss: 1.8023 - accuracy: 0.5490
# Epoch 211/500
#  - 0s - loss: 1.8086 - accuracy: 0.5686
# Epoch 212/500
#  - 0s - loss: 1.7961 - accuracy: 0.5784
# Epoch 213/500
#  - 0s - loss: 1.8041 - accuracy: 0.5686
# Epoch 214/500
#  - 0s - loss: 1.8342 - accuracy: 0.5784
# Epoch 215/500
#  - 0s - loss: 1.7914 - accuracy: 0.5686
# Epoch 216/500
#  - 0s - loss: 1.8007 - accuracy: 0.5588
# Epoch 217/500
#  - 0s - loss: 1.7884 - accuracy: 0.5784
# Epoch 218/500
#  - 0s - loss: 1.7770 - accuracy: 0.5686
# Epoch 219/500
#  - 0s - loss: 1.7812 - accuracy: 0.5980
# Epoch 220/500
#  - 0s - loss: 1.7525 - accuracy: 0.5784
# Epoch 221/500
#  - 0s - loss: 1.7359 - accuracy: 0.6176
# Epoch 222/500
#  - 0s - loss: 1.7350 - accuracy: 0.5882
# Epoch 223/500
#  - 0s - loss: 1.7244 - accuracy: 0.5882
# Epoch 224/500
#  - 0s - loss: 1.7237 - accuracy: 0.6275
# Epoch 225/500
#  - 0s - loss: 1.7126 - accuracy: 0.6176
# Epoch 226/500
#  - 0s - loss: 1.7041 - accuracy: 0.6176
# Epoch 227/500
#  - 0s - loss: 1.6982 - accuracy: 0.6275
# Epoch 228/500
#  - 0s - loss: 1.6942 - accuracy: 0.6275
# Epoch 229/500
#  - 0s - loss: 1.6833 - accuracy: 0.6275
# Epoch 230/500
#  - 0s - loss: 1.6813 - accuracy: 0.6275
# Epoch 231/500
#  - 0s - loss: 1.6723 - accuracy: 0.6078
# Epoch 232/500
#  - 0s - loss: 1.6686 - accuracy: 0.6078
# Epoch 233/500
#  - 0s - loss: 1.6606 - accuracy: 0.6078
# Epoch 234/500
#  - 0s - loss: 1.6539 - accuracy: 0.6176
# Epoch 235/500
#  - 0s - loss: 1.6440 - accuracy: 0.6078
# Epoch 236/500
#  - 0s - loss: 1.6400 - accuracy: 0.6176
# Epoch 237/500
#  - 0s - loss: 1.6301 - accuracy: 0.6275
# Epoch 238/500
#  - 0s - loss: 1.6254 - accuracy: 0.6275
# Epoch 239/500
#  - 0s - loss: 1.6171 - accuracy: 0.6373
# Epoch 240/500
#  - 0s - loss: 1.6097 - accuracy: 0.6373
# Epoch 241/500
#  - 0s - loss: 1.6143 - accuracy: 0.6471
# Epoch 242/500
#  - 0s - loss: 1.6007 - accuracy: 0.6373
# Epoch 243/500
#  - 0s - loss: 1.6031 - accuracy: 0.6275
# Epoch 244/500
#  - 0s - loss: 1.6110 - accuracy: 0.6471
# Epoch 245/500
#  - 0s - loss: 1.5831 - accuracy: 0.6373
# Epoch 246/500
#  - 0s - loss: 1.5793 - accuracy: 0.6373
# Epoch 247/500
#  - 0s - loss: 1.5723 - accuracy: 0.6471
# Epoch 248/500
#  - 0s - loss: 1.5737 - accuracy: 0.6373
# Epoch 249/500
#  - 0s - loss: 1.5693 - accuracy: 0.6471
# Epoch 250/500
#  - 0s - loss: 1.5543 - accuracy: 0.6275
# Epoch 251/500
#  - 0s - loss: 1.5461 - accuracy: 0.6275
# Epoch 252/500
#  - 0s - loss: 1.5388 - accuracy: 0.6471
# Epoch 253/500
#  - 0s - loss: 1.5323 - accuracy: 0.6569
# Epoch 254/500
#  - 0s - loss: 1.5286 - accuracy: 0.6275
# Epoch 255/500
#  - 0s - loss: 1.5206 - accuracy: 0.6275
# Epoch 256/500
#  - 0s - loss: 1.5146 - accuracy: 0.6078
# Epoch 257/500
#  - 0s - loss: 1.5163 - accuracy: 0.6078
# Epoch 258/500
#  - 0s - loss: 1.5068 - accuracy: 0.6176
# Epoch 259/500
#  - 0s - loss: 1.5090 - accuracy: 0.6176
# Epoch 260/500
#  - 0s - loss: 1.5043 - accuracy: 0.6078
# Epoch 261/500
#  - 0s - loss: 1.4872 - accuracy: 0.6471
# Epoch 262/500
#  - 0s - loss: 1.4842 - accuracy: 0.6275
# Epoch 263/500
#  - 0s - loss: 1.4790 - accuracy: 0.6176
# Epoch 264/500
#  - 0s - loss: 1.4707 - accuracy: 0.6373
# Epoch 265/500
#  - 0s - loss: 1.4670 - accuracy: 0.6373
# Epoch 266/500
#  - 0s - loss: 1.4607 - accuracy: 0.6569
# Epoch 267/500
#  - 0s - loss: 1.4576 - accuracy: 0.6373
# Epoch 268/500
#  - 0s - loss: 1.4600 - accuracy: 0.6569
# Epoch 269/500
#  - 0s - loss: 1.4445 - accuracy: 0.6373
# Epoch 270/500
#  - 0s - loss: 1.4386 - accuracy: 0.6275
# Epoch 271/500
#  - 0s - loss: 1.4326 - accuracy: 0.6569
# Epoch 272/500
#  - 0s - loss: 1.4224 - accuracy: 0.6373
# Epoch 273/500
#  - 0s - loss: 1.4175 - accuracy: 0.6471
# Epoch 274/500
#  - 0s - loss: 1.4118 - accuracy: 0.6569
# Epoch 275/500
#  - 0s - loss: 1.4053 - accuracy: 0.6667
# Epoch 276/500
#  - 0s - loss: 1.4000 - accuracy: 0.6569
# Epoch 277/500
#  - 0s - loss: 1.3950 - accuracy: 0.6569
# Epoch 278/500
#  - 0s - loss: 1.3935 - accuracy: 0.6667
# Epoch 279/500
#  - 0s - loss: 1.3808 - accuracy: 0.6569
# Epoch 280/500
#  - 0s - loss: 1.3850 - accuracy: 0.6373
# Epoch 281/500
#  - 0s - loss: 1.3701 - accuracy: 0.6471
# Epoch 282/500
#  - 0s - loss: 1.3649 - accuracy: 0.6569
# Epoch 283/500
#  - 0s - loss: 1.3668 - accuracy: 0.6667
# Epoch 284/500
#  - 0s - loss: 1.3553 - accuracy: 0.6765
# Epoch 285/500
#  - 0s - loss: 1.3534 - accuracy: 0.6765
# Epoch 286/500
#  - 0s - loss: 1.3462 - accuracy: 0.6667
# Epoch 287/500
#  - 0s - loss: 1.3378 - accuracy: 0.6765
# Epoch 288/500
#  - 0s - loss: 1.3303 - accuracy: 0.6765
# Epoch 289/500
#  - 0s - loss: 1.3292 - accuracy: 0.6863
# Epoch 290/500
#  - 0s - loss: 1.3202 - accuracy: 0.6863
# Epoch 291/500
#  - 0s - loss: 1.3153 - accuracy: 0.6961
# Epoch 292/500
#  - 0s - loss: 1.3115 - accuracy: 0.7255
# Epoch 293/500
#  - 0s - loss: 1.3051 - accuracy: 0.7059
# Epoch 294/500
#  - 0s - loss: 1.3020 - accuracy: 0.6863
# Epoch 295/500
#  - 0s - loss: 1.2956 - accuracy: 0.6961
# Epoch 296/500
#  - 0s - loss: 1.2914 - accuracy: 0.7157
# Epoch 297/500
#  - 0s - loss: 1.2925 - accuracy: 0.6863
# Epoch 298/500
#  - 0s - loss: 1.2786 - accuracy: 0.7157
# Epoch 299/500
#  - 0s - loss: 1.2718 - accuracy: 0.6961
# Epoch 300/500
#  - 0s - loss: 1.2707 - accuracy: 0.7059
# Epoch 301/500
#  - 0s - loss: 1.2801 - accuracy: 0.7157
# Epoch 302/500
#  - 0s - loss: 1.3106 - accuracy: 0.6569
# Epoch 303/500
#  - 0s - loss: 1.2653 - accuracy: 0.7157
# Epoch 304/500
#  - 0s - loss: 1.2686 - accuracy: 0.6863
# Epoch 305/500
#  - 0s - loss: 1.2573 - accuracy: 0.7059
# Epoch 306/500
#  - 0s - loss: 1.2500 - accuracy: 0.7157
# Epoch 307/500
#  - 0s - loss: 1.2337 - accuracy: 0.7059
# Epoch 308/500
#  - 0s - loss: 1.2292 - accuracy: 0.6863
# Epoch 309/500
#  - 0s - loss: 1.2339 - accuracy: 0.7157
# Epoch 310/500
#  - 0s - loss: 1.2273 - accuracy: 0.7255
# Epoch 311/500
#  - 0s - loss: 1.2108 - accuracy: 0.7255
# Epoch 312/500
#  - 0s - loss: 1.2132 - accuracy: 0.7059
# Epoch 313/500
#  - 0s - loss: 1.2068 - accuracy: 0.7353
# Epoch 314/500
#  - 0s - loss: 1.1994 - accuracy: 0.7255
# Epoch 315/500
#  - 0s - loss: 1.2138 - accuracy: 0.7255
# Epoch 316/500
#  - 0s - loss: 1.1927 - accuracy: 0.7255
# Epoch 317/500
#  - 0s - loss: 1.1870 - accuracy: 0.7549
# Epoch 318/500
#  - 0s - loss: 1.2182 - accuracy: 0.7157
# Epoch 319/500
#  - 0s - loss: 1.1863 - accuracy: 0.7353
# Epoch 320/500
#  - 0s - loss: 1.1745 - accuracy: 0.7549
# Epoch 321/500
#  - 0s - loss: 1.1694 - accuracy: 0.7353
# Epoch 322/500
#  - 0s - loss: 1.1637 - accuracy: 0.7451
# Epoch 323/500
#  - 0s - loss: 1.1548 - accuracy: 0.7647
# Epoch 324/500
#  - 0s - loss: 1.1494 - accuracy: 0.7647
# Epoch 325/500
#  - 0s - loss: 1.1435 - accuracy: 0.7745
# Epoch 326/500
#  - 0s - loss: 1.1394 - accuracy: 0.7549
# Epoch 327/500
#  - 0s - loss: 1.1400 - accuracy: 0.7549
# Epoch 328/500
#  - 0s - loss: 1.1322 - accuracy: 0.7647
# Epoch 329/500
#  - 0s - loss: 1.1289 - accuracy: 0.7647
# Epoch 330/500
#  - 0s - loss: 1.1211 - accuracy: 0.7549
# Epoch 331/500
#  - 0s - loss: 1.1144 - accuracy: 0.7745
# Epoch 332/500
#  - 0s - loss: 1.1126 - accuracy: 0.7647
# Epoch 333/500
#  - 0s - loss: 1.1115 - accuracy: 0.7647
# Epoch 334/500
#  - 0s - loss: 1.1079 - accuracy: 0.8137
# Epoch 335/500
#  - 0s - loss: 1.0960 - accuracy: 0.8039
# Epoch 336/500
#  - 0s - loss: 1.0926 - accuracy: 0.7647
# Epoch 337/500
#  - 0s - loss: 1.0847 - accuracy: 0.7745
# Epoch 338/500
#  - 0s - loss: 1.0841 - accuracy: 0.7647
# Epoch 339/500
#  - 0s - loss: 1.0830 - accuracy: 0.7647
# Epoch 340/500
#  - 0s - loss: 1.0796 - accuracy: 0.7549
# Epoch 341/500
#  - 0s - loss: 1.0720 - accuracy: 0.7549
# Epoch 342/500
#  - 0s - loss: 1.0651 - accuracy: 0.7745
# Epoch 343/500
#  - 0s - loss: 1.0680 - accuracy: 0.7549
# Epoch 344/500
#  - 0s - loss: 1.0555 - accuracy: 0.7647
# Epoch 345/500
#  - 0s - loss: 1.0570 - accuracy: 0.7549
# Epoch 346/500
#  - 0s - loss: 1.0471 - accuracy: 0.7549
# Epoch 347/500
#  - 0s - loss: 1.0471 - accuracy: 0.7647
# Epoch 348/500
#  - 0s - loss: 1.0427 - accuracy: 0.7647
# Epoch 349/500
#  - 0s - loss: 1.0397 - accuracy: 0.7745
# Epoch 350/500
#  - 0s - loss: 1.0364 - accuracy: 0.7647
# Epoch 351/500
#  - 0s - loss: 1.0333 - accuracy: 0.7549
# Epoch 352/500
#  - 0s - loss: 1.0237 - accuracy: 0.7647
# Epoch 353/500
#  - 0s - loss: 1.0230 - accuracy: 0.7745
# Epoch 354/500
#  - 0s - loss: 1.0136 - accuracy: 0.7745
# Epoch 355/500
#  - 0s - loss: 1.0097 - accuracy: 0.7745
# Epoch 356/500
#  - 0s - loss: 1.0044 - accuracy: 0.7549
# Epoch 357/500
#  - 0s - loss: 1.0028 - accuracy: 0.7647
# Epoch 358/500
#  - 0s - loss: 1.0054 - accuracy: 0.7353
# Epoch 359/500
#  - 0s - loss: 1.0187 - accuracy: 0.7745
# Epoch 360/500
#  - 0s - loss: 0.9921 - accuracy: 0.7549
# Epoch 361/500
#  - 0s - loss: 0.9961 - accuracy: 0.7745
# Epoch 362/500
#  - 0s - loss: 0.9900 - accuracy: 0.7941
# Epoch 363/500
#  - 0s - loss: 0.9833 - accuracy: 0.8137
# Epoch 364/500
#  - 0s - loss: 0.9852 - accuracy: 0.8137
# Epoch 365/500
#  - 0s - loss: 0.9678 - accuracy: 0.8137
# Epoch 366/500
#  - 0s - loss: 0.9643 - accuracy: 0.8137
# Epoch 367/500
#  - 0s - loss: 0.9609 - accuracy: 0.8333
# Epoch 368/500
#  - 0s - loss: 0.9568 - accuracy: 0.8333
# Epoch 369/500
#  - 0s - loss: 0.9518 - accuracy: 0.8529
# Epoch 370/500
#  - 0s - loss: 0.9438 - accuracy: 0.8431
# Epoch 371/500
#  - 0s - loss: 0.9441 - accuracy: 0.8235
# Epoch 372/500
#  - 0s - loss: 0.9378 - accuracy: 0.8333
# Epoch 373/500
#  - 0s - loss: 0.9320 - accuracy: 0.8333
# Epoch 374/500
#  - 0s - loss: 0.9302 - accuracy: 0.8333
# Epoch 375/500
#  - 0s - loss: 0.9261 - accuracy: 0.8333
# Epoch 376/500
#  - 0s - loss: 0.9230 - accuracy: 0.8333
# Epoch 377/500
#  - 0s - loss: 0.9161 - accuracy: 0.8333
# Epoch 378/500
#  - 0s - loss: 0.9136 - accuracy: 0.8431
# Epoch 379/500
#  - 0s - loss: 0.9111 - accuracy: 0.8431
# Epoch 380/500
#  - 0s - loss: 0.9069 - accuracy: 0.8627
# Epoch 381/500
#  - 0s - loss: 0.9052 - accuracy: 0.8333
# Epoch 382/500
#  - 0s - loss: 0.8998 - accuracy: 0.8627
# Epoch 383/500
#  - 0s - loss: 0.8924 - accuracy: 0.8725
# Epoch 384/500
#  - 0s - loss: 0.8883 - accuracy: 0.8725
# Epoch 385/500
#  - 0s - loss: 0.8863 - accuracy: 0.8529
# Epoch 386/500
#  - 0s - loss: 0.8821 - accuracy: 0.8529
# Epoch 387/500
#  - 0s - loss: 0.8778 - accuracy: 0.8529
# Epoch 388/500
#  - 0s - loss: 0.8743 - accuracy: 0.8627
# Epoch 389/500
#  - 0s - loss: 0.8722 - accuracy: 0.8627
# Epoch 390/500
#  - 0s - loss: 0.8680 - accuracy: 0.8627
# Epoch 391/500
#  - 0s - loss: 0.8624 - accuracy: 0.8627
# Epoch 392/500
#  - 0s - loss: 0.8571 - accuracy: 0.8725
# Epoch 393/500
#  - 0s - loss: 0.8550 - accuracy: 0.8725
# Epoch 394/500
#  - 0s - loss: 0.8651 - accuracy: 0.8627
# Epoch 395/500
#  - 0s - loss: 0.8758 - accuracy: 0.8431
# Epoch 396/500
#  - 0s - loss: 0.8956 - accuracy: 0.8529
# Epoch 397/500
#  - 0s - loss: 0.8793 - accuracy: 0.8431
# Epoch 398/500
#  - 0s - loss: 0.8638 - accuracy: 0.8725
# Epoch 399/500
#  - 0s - loss: 0.8735 - accuracy: 0.8627
# Epoch 400/500
#  - 0s - loss: 0.8336 - accuracy: 0.8824
# Epoch 401/500
#  - 0s - loss: 0.8301 - accuracy: 0.8922
# Epoch 402/500
#  - 0s - loss: 0.8349 - accuracy: 0.8725
# Epoch 403/500
#  - 0s - loss: 0.8190 - accuracy: 0.8922
# Epoch 404/500
#  - 0s - loss: 0.8206 - accuracy: 0.8824
# Epoch 405/500
#  - 0s - loss: 0.8126 - accuracy: 0.8725
# Epoch 406/500
#  - 0s - loss: 0.8091 - accuracy: 0.8725
# Epoch 407/500
#  - 0s - loss: 0.8054 - accuracy: 0.8725
# Epoch 408/500
#  - 0s - loss: 0.8002 - accuracy: 0.8725
# Epoch 409/500
#  - 0s - loss: 0.7921 - accuracy: 0.8824
# Epoch 410/500
#  - 0s - loss: 0.7887 - accuracy: 0.8922
# Epoch 411/500
#  - 0s - loss: 0.7909 - accuracy: 0.8824
# Epoch 412/500
#  - 0s - loss: 0.7933 - accuracy: 0.8922
# Epoch 413/500
#  - 0s - loss: 0.7815 - accuracy: 0.8725
# Epoch 414/500
#  - 0s - loss: 0.7773 - accuracy: 0.8922
# Epoch 415/500
#  - 0s - loss: 0.7734 - accuracy: 0.8922
# Epoch 416/500
#  - 0s - loss: 0.7686 - accuracy: 0.8922
# Epoch 417/500
#  - 0s - loss: 0.7647 - accuracy: 0.9020
# Epoch 418/500
#  - 0s - loss: 0.7596 - accuracy: 0.9020
# Epoch 419/500
#  - 0s - loss: 0.7576 - accuracy: 0.9020
# Epoch 420/500
#  - 0s - loss: 0.7535 - accuracy: 0.9020
# Epoch 421/500
#  - 0s - loss: 0.7492 - accuracy: 0.9118
# Epoch 422/500
#  - 0s - loss: 0.7468 - accuracy: 0.9020
# Epoch 423/500
#  - 0s - loss: 0.7418 - accuracy: 0.8922
# Epoch 424/500
#  - 0s - loss: 0.7383 - accuracy: 0.9020
# Epoch 425/500
#  - 0s - loss: 0.7366 - accuracy: 0.8824
# Epoch 426/500
#  - 0s - loss: 0.7320 - accuracy: 0.8725
# Epoch 427/500
#  - 0s - loss: 0.7308 - accuracy: 0.9020
# Epoch 428/500
#  - 0s - loss: 0.7253 - accuracy: 0.9020
# Epoch 429/500
#  - 0s - loss: 0.7218 - accuracy: 0.9020
# Epoch 430/500
#  - 0s - loss: 0.7171 - accuracy: 0.9020
# Epoch 431/500
#  - 0s - loss: 0.7158 - accuracy: 0.9020
# Epoch 432/500
#  - 0s - loss: 0.7130 - accuracy: 0.8922
# Epoch 433/500
#  - 0s - loss: 0.7085 - accuracy: 0.9020
# Epoch 434/500
#  - 0s - loss: 0.7049 - accuracy: 0.9020
# Epoch 435/500
#  - 0s - loss: 0.7041 - accuracy: 0.9020
# Epoch 436/500
#  - 0s - loss: 0.7005 - accuracy: 0.8922
# Epoch 437/500
#  - 0s - loss: 0.6942 - accuracy: 0.8922
# Epoch 438/500
#  - 0s - loss: 0.6944 - accuracy: 0.9020
# Epoch 439/500
#  - 0s - loss: 0.6980 - accuracy: 0.8922
# Epoch 440/500
#  - 0s - loss: 0.6911 - accuracy: 0.8922
# Epoch 441/500
#  - 0s - loss: 0.6874 - accuracy: 0.9020
# Epoch 442/500
#  - 0s - loss: 0.6882 - accuracy: 0.9020
# Epoch 443/500
#  - 0s - loss: 0.6870 - accuracy: 0.8922
# Epoch 444/500
#  - 0s - loss: 0.6763 - accuracy: 0.9020
# Epoch 445/500
#  - 0s - loss: 0.6773 - accuracy: 0.9020
# Epoch 446/500
#  - 0s - loss: 0.6763 - accuracy: 0.9020
# Epoch 447/500
#  - 0s - loss: 0.6657 - accuracy: 0.9020
# Epoch 448/500
#  - 0s - loss: 0.6587 - accuracy: 0.9118
# Epoch 449/500
#  - 0s - loss: 0.6569 - accuracy: 0.9118
# Epoch 450/500
#  - 0s - loss: 0.6538 - accuracy: 0.9118
# Epoch 451/500
#  - 0s - loss: 0.6497 - accuracy: 0.9118
# Epoch 452/500
#  - 0s - loss: 0.6460 - accuracy: 0.9118
# Epoch 453/500
#  - 0s - loss: 0.6464 - accuracy: 0.9118
# Epoch 454/500
#  - 0s - loss: 0.6406 - accuracy: 0.9118
# Epoch 455/500
#  - 0s - loss: 0.6405 - accuracy: 0.9118
# Epoch 456/500
#  - 0s - loss: 0.6361 - accuracy: 0.9118
# Epoch 457/500
#  - 0s - loss: 0.6324 - accuracy: 0.9118
# Epoch 458/500
#  - 0s - loss: 0.6271 - accuracy: 0.9118
# Epoch 459/500
#  - 0s - loss: 0.6253 - accuracy: 0.9118
# Epoch 460/500
#  - 0s - loss: 0.6219 - accuracy: 0.9118
# Epoch 461/500
#  - 0s - loss: 0.6207 - accuracy: 0.9118
# Epoch 462/500
#  - 0s - loss: 0.6167 - accuracy: 0.9118
# Epoch 463/500
#  - 0s - loss: 0.6150 - accuracy: 0.9020
# Epoch 464/500
#  - 0s - loss: 0.6085 - accuracy: 0.9118
# Epoch 465/500
#  - 0s - loss: 0.6110 - accuracy: 0.9118
# Epoch 466/500
#  - 0s - loss: 0.6102 - accuracy: 0.9118
# Epoch 467/500
#  - 0s - loss: 0.6049 - accuracy: 0.9118
# Epoch 468/500
#  - 0s - loss: 0.6003 - accuracy: 0.9118
# Epoch 469/500
#  - 0s - loss: 0.5969 - accuracy: 0.9020
# Epoch 470/500
#  - 0s - loss: 0.5945 - accuracy: 0.9118
# Epoch 471/500
#  - 0s - loss: 0.5900 - accuracy: 0.9118
# Epoch 472/500
#  - 0s - loss: 0.5946 - accuracy: 0.9118
# Epoch 473/500
#  - 0s - loss: 0.6201 - accuracy: 0.9020
# Epoch 474/500
#  - 0s - loss: 0.5876 - accuracy: 0.9216
# Epoch 475/500
#  - 0s - loss: 0.6143 - accuracy: 0.9118
# Epoch 476/500
#  - 0s - loss: 0.5906 - accuracy: 0.9118
# Epoch 477/500
#  - 0s - loss: 0.5815 - accuracy: 0.9118
# Epoch 478/500
#  - 0s - loss: 0.5751 - accuracy: 0.9216
# Epoch 479/500
#  - 0s - loss: 0.5702 - accuracy: 0.9118
# Epoch 480/500
#  - 0s - loss: 0.5651 - accuracy: 0.9118
# Epoch 481/500
#  - 0s - loss: 0.5647 - accuracy: 0.9020
# Epoch 482/500
#  - 0s - loss: 0.5591 - accuracy: 0.9020
# Epoch 483/500
#  - 0s - loss: 0.5572 - accuracy: 0.9020
# Epoch 484/500
#  - 0s - loss: 0.5540 - accuracy: 0.9216
# Epoch 485/500
#  - 0s - loss: 0.5547 - accuracy: 0.9314
# Epoch 486/500
#  - 0s - loss: 0.5479 - accuracy: 0.9216
# Epoch 487/500
#  - 0s - loss: 0.5490 - accuracy: 0.9216
# Epoch 488/500
#  - 0s - loss: 0.5424 - accuracy: 0.9216
# Epoch 489/500
#  - 0s - loss: 0.5403 - accuracy: 0.9314
# Epoch 490/500
#  - 0s - loss: 0.5378 - accuracy: 0.9216
# Epoch 491/500
#  - 0s - loss: 0.5355 - accuracy: 0.9314
# Epoch 492/500
#  - 0s - loss: 0.5392 - accuracy: 0.9314
# Epoch 493/500
#  - 0s - loss: 0.5282 - accuracy: 0.9314
# Epoch 494/500
#  - 0s - loss: 0.5370 - accuracy: 0.9314
# Epoch 495/500
#  - 0s - loss: 0.5400 - accuracy: 0.9020
# Epoch 496/500
#  - 0s - loss: 0.5366 - accuracy: 0.9216
# Epoch 497/500
#  - 0s - loss: 0.5241 - accuracy: 0.9216
# Epoch 498/500
#  - 0s - loss: 0.5279 - accuracy: 0.9118
# Epoch 499/500
#  - 0s - loss: 0.5157 - accuracy: 0.9118
# Epoch 500/500
#  - 0s - loss: 0.5225 - accuracy: 0.9216

# %% [markdown]
# EVALUATE

# %%
# evaluate model
print(generate_seq(model, tokenizer, max_length-1, 'The slings and', 4))
print(generate_seq(model, tokenizer, max_length-1, 'Or to', 4))
print(generate_seq(model, tokenizer, max_length-1, 'Must give', 4))
# Out:
# The slings and arrows of outrageous fortune
# Or to take arms against a
# Must give us pause—there's the respect
